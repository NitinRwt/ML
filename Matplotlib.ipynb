# %% [markdown]
# # Matplotlib Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
#keyword argument marker to emphasize each point with a specified marker
import matplotlib.pyplot as plt
import numpy as np
plt.title("Sports Watch Data")
ypoints = np.array([3, 10, 3, 10])
plt.grid()
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.grid()
plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %% [markdown]
# # BlackPink

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 15, 25, 15])
mylabels = ["Lisa", "Rose", "jiso", "Jenne"]
mycolors = ["black", "hotpink", "black", "hotpink"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend(title = "Four Idols:")
plt.show()
