# %% [markdown]
# ## Type of triangle using oops

# %%
class para():
    def take(self):
        self.s1 = int(input("enter side 1:"))
        self.s2 = int(input("enter side 2:"))
        self.s3 = int(input("enter side 3:"))

class equ(para):
    def check(self):
        if self.s1 == self.s2 == self.s3:
            print("Equilateral triangle")
        else:
            print("not an equilateral triangle")

class iso(para):
    def check(self):
        if self.s1 == self.s2 or self.s2 == self.s3 or self.s3 == self.s1:
            print("Isosceles triangle")
        else:
            print("not an isosceles triangle")

class rat(para):
    def check(self):
        if (self.s1 ** 2) + (self.s2 ** 2) == (self.s3 ** 2) or \
           (self.s2 ** 2) + (self.s3 ** 2) == (self.s1 ** 2) or \
           (self.s3 ** 2) + (self.s1 ** 2) == (self.s2 ** 2):
            print("Right-angled triangle")
        else:
            print("not a right-angled triangle")

class scal(para):
    def check(self):
        if self.s1 != self.s2 != self.s3:
            print("Scalene triangle")
        else:
            print("not a scalene triangle")

E = equ()
I = iso()
R = rat()
S = scal()

print("Enter for what type you want to check")
print("++++++++++++++++++++++++++++++++++++++")
print("equilateral\n isosceles\n right angled triangle\n scalene")

user = input().lower()
if user == "equilateral":
    E.take()
    E.check()
elif user == "isosceles":
    I.take()
    I.check()
elif user == "right angled" or user == "right-angled triangle":
    R.take()
    R.check()
elif user == "scalene":
    S.take()
    S.check()
else:
    print('Invalid input')
# Out:
# Enter for what type you want to check
# ++++++++++++++++++++++++++++++++++++++
# equilateral
#  isosceles
#  right angled triangle
#  scalene
# 1
# Invalid input

# %% [markdown]
# # choosing shapes and finding its properties

# %%
class shape():
    def takeforR(self):
        self.l=int(input("enter length:"))
        self.b=int(input("enter breadth:"))
    def takeforS(self):
        self.s=int(input("enter side:"))
    #def takeforTS(self):
       # self.s1=int(input("enter side 1:"))
        #self.s2=int(input("enter side 2:"))
        #self.s3=int(input("enter side 3:"))
    #def takeforC(self):
        #self.r=int(input("enter radius:"))
class rec(shape):
    def area(self):
        print(f"area of rectangle is {self.l*self.b}")
    def peri(self):
        print(f"perimeter of rectangle is {2*(self.l+self.b)}")
class squ(shape):
    def area(self):
        print(f"area of square is {self.s**2}")
    def peri(self):
        print(f"perimeter of the square is {self.s*4}")


RE=rec()
SQ=squ()

user=input("Enter your desired shape:\nRectangle\nSquared")
prop=input("find area or find perimeter:")
new_prop=prop.lower()
new_user=user.lower()
if new_user=="rectangle":
    if new_prop=="find area" or "area":
        RE.takeforR()
        RE.area()
    elif new_prop=="find perimeter" or "perimeter":
        RE.takeforR()
        RE.peri()
    else:
        print("invalid")
elif new_user=="square":
    if new_prop=="find area" or "area":
        SQ.takeforS()
        SQ.area()
    elif new_prop=="find perimeter" or "perimeter":
        SQ.takeforS()
        SQ.peri()
    else:
        print("invalid")
else:
    print("invalid")
